# %%
heads = 0
total = 0
points = []

for _ in range(1000):
    # re-arrange the following lines, fixing indentation as needed
    flip = choice(['H','T'])
    total = total + 1
    if flip == "H":
        heads = heads + 1
    ex_prob = heads/total
    points.append( (total,ex_prob) )

show(
    line(points, color="blue")+line([(1,0.5),(1000,0.5)], color="red"),
    axes_labels=["Trials","Exp. Prob."],
    ymin=0,
    ymax=1
)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
[x for x in range(3,2021) if x%10 in [4,7,9]]
# Out:
# [4,
#  7,
#  9,
#  14,
#  17,
#  19,
#  24,
#  27,
#  29,
#  34,
#  37,
#  39,
#  44,
#  47,
#  49,
#  54,
#  57,
#  59,
#  64,
#  67,
#  69,
#  74,
#  77,
#  79,
#  84,
#  87,
#  89,
#  94,
#  97,
#  99,
#  104,
#  107,
#  109,
#  114,
#  117,
#  119,
#  124,
#  127,
#  129,
#  134,
#  137,
#  139,
#  144,
#  147,
#  149,
#  154,
#  157,
#  159,
#  164,
#  167,
#  169,
#  174,
#  177,
#  179,
#  184,
#  187,
#  189,
#  194,
#  197,
#  199,
#  204,
#  207,
#  209,
#  214,
#  217,
#  219,
#  224,
#  227,
#  229,
#  234,
#  237,
#  239,
#  244,
#  247,
#  249,
#  254,
#  257,
#  259,
#  264,
#  267,
#  269,
#  274,
#  277,
#  279,
#  284,
#  287,
#  289,
#  294,
#  297,
#  299,
#  304,
#  307,
#  309,
#  314,
#  317,
#  319,
#  324,
#  327,
#  329,
#  334,
#  337,
#  339,
#  344,
#  347,
#  349,
#  354,
#  357,
#  359,
#  364,
#  367,
#  369,
#  374,
#  377,
#  379,
#  384,
#  387,
#  389,
#  394,
#  397,
#  399,
#  404,
#  407,
#  409,
#  414,
#  417,
#  419,
#  424,
#  427,
#  429,
#  434,
#  437,
#  439,
#  444,
#  447,
#  449,
#  454,
#  457,
#  459,
#  464,
#  467,
#  469,
#  474,
#  477,
#  479,
#  484,
#  487,
#  489,
#  494,
#  497,
#  499,
#  504,
#  507,
#  509,
#  514,
#  517,
#  519,
#  524,
#  527,
#  529,
#  534,
#  537,
#  539,
#  544,
#  547,
#  549,
#  554,
#  557,
#  559,
#  564,
#  567,
#  569,
#  574,
#  577,
#  579,
#  584,
#  587,
#  589,
#  594,
#  597,
#  599,
#  604,
#  607,
#  609,
#  614,
#  617,
#  619,
#  624,
#  627,
#  629,
#  634,
#  637,
#  639,
#  644,
#  647,
#  649,
#  654,
#  657,
#  659,
#  664,
#  667,
#  669,
#  674,
#  677,
#  679,
#  684,
#  687,
#  689,
#  694,
#  697,
#  699,
#  704,
#  707,
#  709,
#  714,
#  717,
#  719,
#  724,
#  727,
#  729,
#  734,
#  737,
#  739,
#  744,
#  747,
#  749,
#  754,
#  757,
#  759,
#  764,
#  767,
#  769,
#  774,
#  777,
#  779,
#  784,
#  787,
#  789,
#  794,
#  797,
#  799,
#  804,
#  807,
#  809,
#  814,
#  817,
#  819,
#  824,
#  827,
#  829,
#  834,
#  837,
#  839,
#  844,
#  847,
#  849,
#  854,
#  857,
#  859,
#  864,
#  867,
#  869,
#  874,
#  877,
#  879,
#  884,
#  887,
#  889,
#  894,
#  897,
#  899,
#  904,
#  907,
#  909,
#  914,
#  917,
#  919,
#  924,
#  927,
#  929,
#  934,
#  937,
#  939,
#  944,
#  947,
#  949,
#  954,
#  957,
#  959,
#  964,
#  967,
#  969,
#  974,
#  977,
#  979,
#  984,
#  987,
#  989,
#  994,
#  997,
#  999,
#  1004,
#  1007,
#  1009,
#  1014,
#  1017,
#  1019,
#  1024,
#  1027,
#  1029,
#  1034,
#  1037,
#  1039,
#  1044,
#  1047,
#  1049,
#  1054,
#  1057,
#  1059,
#  1064,
#  1067,
#  1069,
#  1074,
#  1077,
#  1079,
#  1084,
#  1087,
#  1089,
#  1094,
#  1097,
#  1099,
#  1104,
#  1107,
#  1109,
#  1114,
#  1117,
#  1119,
#  1124,
#  1127,
#  1129,
#  1134,
#  1137,
#  1139,
#  1144,
#  1147,
#  1149,
#  1154,
#  1157,
#  1159,
#  1164,
#  1167,
#  1169,
#  1174,
#  1177,
#  1179,
#  1184,
#  1187,
#  1189,
#  1194,
#  1197,
#  1199,
#  1204,
#  1207,
#  1209,
#  1214,
#  1217,
#  1219,
#  1224,
#  1227,
#  1229,
#  1234,
#  1237,
#  1239,
#  1244,
#  1247,
#  1249,
#  1254,
#  1257,
#  1259,
#  1264,
#  1267,
#  1269,
#  1274,
#  1277,
#  1279,
#  1284,
#  1287,
#  1289,
#  1294,
#  1297,
#  1299,
#  1304,
#  1307,
#  1309,
#  1314,
#  1317,
#  1319,
#  1324,
#  1327,
#  1329,
#  1334,
#  1337,
#  1339,
#  1344,
#  1347,
#  1349,
#  1354,
#  1357,
#  1359,
#  1364,
#  1367,
#  1369,
#  1374,
#  1377,
#  1379,
#  1384,
#  1387,
#  1389,
#  1394,
#  1397,
#  1399,
#  1404,
#  1407,
#  1409,
#  1414,
#  1417,
#  1419,
#  1424,
#  1427,
#  1429,
#  1434,
#  1437,
#  1439,
#  1444,
#  1447,
#  1449,
#  1454,
#  1457,
#  1459,
#  1464,
#  1467,
#  1469,
#  1474,
#  1477,
#  1479,
#  1484,
#  1487,
#  1489,
#  1494,
#  1497,
#  1499,
#  1504,
#  1507,
#  1509,
#  1514,
#  1517,
#  1519,
#  1524,
#  1527,
#  1529,
#  1534,
#  1537,
#  1539,
#  1544,
#  1547,
#  1549,
#  1554,
#  1557,
#  1559,
#  1564,
#  1567,
#  1569,
#  1574,
#  1577,
#  1579,
#  1584,
#  1587,
#  1589,
#  1594,
#  1597,
#  1599,
#  1604,
#  1607,
#  1609,
#  1614,
#  1617,
#  1619,
#  1624,
#  1627,
#  1629,
#  1634,
#  1637,
#  1639,
#  1644,
#  1647,
#  1649,
#  1654,
#  1657,
#  1659,
#  1664,
#  1667,
#  1669,
#  1674,
#  1677,
#  1679,
#  1684,
#  1687,
#  1689,
#  1694,
#  1697,
#  1699,
#  1704,
#  1707,
#  1709,
#  1714,
#  1717,
#  1719,
#  1724,
#  1727,
#  1729,
#  1734,
#  1737,
#  1739,
#  1744,
#  1747,
#  1749,
#  1754,
#  1757,
#  1759,
#  1764,
#  1767,
#  1769,
#  1774,
#  1777,
#  1779,
#  1784,
#  1787,
#  1789,
#  1794,
#  1797,
#  1799,
#  1804,
#  1807,
#  1809,
#  1814,
#  1817,
#  1819,
#  1824,
#  1827,
#  1829,
#  1834,
#  1837,
#  1839,
#  1844,
#  1847,
#  1849,
#  1854,
#  1857,
#  1859,
#  1864,
#  1867,
#  1869,
#  1874,
#  1877,
#  1879,
#  1884,
#  1887,
#  1889,
#  1894,
#  1897,
#  1899,
#  1904,
#  1907,
#  1909,
#  1914,
#  1917,
#  1919,
#  1924,
#  1927,
#  1929,
#  1934,
#  1937,
#  1939,
#  1944,
#  1947,
#  1949,
#  1954,
#  1957,
#  1959,
#  1964,
#  1967,
#  1969,
#  1974,
#  1977,
#  1979,
#  1984,
#  1987,
#  1989,
#  1994,
#  1997,
#  1999,
#  2004,
#  2007,
#  2009,
#  2014,
#  2017,
#  2019]
